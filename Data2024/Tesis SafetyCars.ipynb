# %%
import fastf1
import fastf1.plotting
import pandas as pd 
import numpy as np
import re
from matplotlib import pyplot as plt
print(fastf1.__version__)
from fastf1 import utils
from fastf1.core import Laps
import fastf1.plotting
import matplotlib.pyplot as plt


fastf1.plotting.setup_mpl(misc_mpl_mods=False)
# Out:
# 3.0.7

# %%
import fastf1
import pandas as pd

# Load the session data
fastf1.Cache.enable_cache("/Users/ainefernandez/documents/itam/8SEMESTRE/F1 Python")


session = fastf1.get_session(2023, 'Australia', 'R')
session.load()

# Define the labeling function
def label_track_status(status):
    if pd.isna(status):
        return 'Unknown'
    if '4' in status:
        return 'Safety Car'
    if '6' in status:
        return 'Virtual Safety Car'
    return {
        '1': 'Green flag',
        '2': 'Yellow flag',
        '5': 'Red Flag',
    }.get(status, 'Unknown')

# Extract lap data
laps = session.laps

# Create the final DataFrame
df = laps[['LapNumber', 'TrackStatus']].copy()
df['gp'] = 'Australia'
df['year'] = 2023
df['label_trackstatus'] = df['TrackStatus'].apply(label_track_status)

# Rename columns for clarity
df.rename(columns={'LapNumber': 'lapNumber', 'TrackStatus': 'trackstatus', 'label_trackstatus': 'label_trackstatus'}, inplace=True)

# Display the DataFrame
print(df)
# Out:
# core           INFO 	Loading data for Australian Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '44', '14', '18', '11', '4', '27', '81', '24', '22', '77', '55', '10', '31', '21', '2', '20', '63', '23', '16']
#       lapNumber trackstatus         gp  year label_trackstatus
# ...

# %%
import fastf1
import pandas as pd

# Enable FastF1 cache
fastf1.Cache.enable_cache("/Users/ainefernandez/documents/itam/8SEMESTRE/F1 Python")

# Define the years and Grand Prix to process
years = [2019, 2020, 2021, 2022, 2023]
gps = ["Bahrain", "Saudi Arabia", "Australia", "Japan", "China",
       "Miami", "Imola", "Monaco", "Spain", "Canada",
       "Austria", "Great Britain", "Hungary", "Belgium", "Netherlands",
       "Azerbaijan", "Singapore", "Austin", "Mexico", "Brazil",
       "Qatar", "Abu Dhabi", "Monza"]

# Function to label track status
def label_track_status(status):
    if pd.isna(status):
        return 'Unknown'
    status_str = str(status)  # Convert status to string for checking
    if '4' in status_str:
        return 'Safety Car'
    if '6' in status_str:
        return 'Virtual Safety Car'
    if '5' in status_str:
        return 'Red Flag'
    return {
        '1': 'Green flag',
        '2': 'Yellow flag',
    }.get(status_str, 'Unknown')

# Initialize an empty DataFrame to store all results
all_results = pd.DataFrame()

for year in years:
    for gp in gps:
        try:
            # Load the session
            session = fastf1.get_session(year, gp, 'R')
            session.load()

            # Extract all laps (from all drivers)
            laps = session.laps

            # Drop duplicate lap numbers (keeping only the first occurrence)
            laps = laps.drop_duplicates(subset='LapNumber', keep='first')

            # Label track statuses
            laps['Label'] = laps['TrackStatus'].apply(label_track_status)

            # Add the GP name and year columns
            laps['GP'] = gp
            laps['Year'] = year

            # Select only the necessary columns
            result = laps[['LapNumber', 'GP', 'Year', 'TrackStatus', 'Label']]

            # Append the result to the all_results DataFrame
            all_results = pd.concat([all_results, result], ignore_index=True)

        except Exception as e:
            # Handle exceptions (e.g., if the session data is not available)
            print(f"Could not load data for {gp} {year}: {e}")

# Save the complete DataFrame to a CSV file
all_results.to_csv('TesisSafetyCars.csv', index=False)

# Print a success message
print("Data saved to 'TesisSafetyCars.csv'")
# Out:
# core           INFO 	Loading data for Bahrain Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '16', '33', '5', '4', '7', '10', '23', '11', '99', '26', '20', '18', '63', '88', '27', '3', '55', '8']
# ...

# %%
import fastf1
import pandas as pd

# Enable FastF1 cache
fastf1.Cache.enable_cache("/Users/ainefernandez/documents/itam/8SEMESTRE/F1 Python")

# Define the years and Grand Prix to process
years = [2019, 2020, 2021, 2022, 2023]
gps = ["Bahrain", "Saudi Arabia", "Australia", "Japan", "China",
       "Miami", "Imola", "Monaco", "Spain", "Canada",
       "Austria", "Great Britain", "Hungary", "Belgium", "Netherlands",
       "Azerbaijan", "Singapore", "Austin", "Mexico", "Brazil",
       "Qatar", "Abu Dhabi", "Monza"]

# Function to label track status
def label_track_status(status):
    if pd.isna(status):
        return 'Unknown'
    status_str = str(status)  # Convert status to string for checking
    if '4' in status_str:
        return 'Safety Car'
    if '6' in status_str:
        return 'Virtual Safety Car'
    if '5' in status_str:
        return 'Red Flag'
    return {
        '1': 'Green flag',
        '2': 'Yellow flag',
    }.get(status_str, 'Unknown')

# Initialize an empty DataFrame to store all results
all_results = pd.DataFrame()

for year in years:
    for gp in gps:
        try:
            # Load the session for each Grand Prix
            session = fastf1.get_session(year, gp, 'R')
            session.load()

            # Extract all laps (from all drivers)
            laps = session.laps

            # Drop duplicate lap numbers (keeping only the first occurrence)
            laps = laps.drop_duplicates(subset='LapNumber', keep='first')

            # Label track statuses
            laps['Label'] = laps['TrackStatus'].apply(label_track_status)

            # Add the GP name and year columns
            laps['GP'] = gp
            laps['Year'] = year

            # Select only the necessary columns
            result = laps[['LapNumber', 'GP', 'Year', 'TrackStatus', 'Label']]

            # Append the result to the all_results DataFrame
            all_results = pd.concat([all_results, result], ignore_index=True)

        except Exception as e:
            # Handle exceptions (e.g., if the session data is not available)
            print(f"Could not load data for {gp} {year}: {e}")

# Save the complete DataFrame to a CSV file
all_results.to_csv('TesisSafetyCars_AllGPs.csv', index=False)

# Print a success message
print("Data saved to 'TesisSafetyCars_AllGPs.csv'")

# %%
year =2019
gps = ["Bahrain", "China", "Australia", "Japan",
       "Monaco", "Spain", "Canada",
       "Austria", "Great Britain", "Hungary", "Belgium",
       "Azerbaijan", "Singapore", "Austin", "Mexico", "Brazil",
       "Abu Dhabi", "Monza"]
year =2020
gps = ["Bahrain", "Monaco", "Spain", "Canada",
       "Austria", "Great Britain", "Hungary", "Belgium",
       "Abu Dhabi", "Monza"]
year =2021
gps = ["Bahrain", "China", "Australia", "Japan",
       "Monaco", "Spain", "Canada", "Imola,"
       "Austria", "Great Britain", "Hungary", "Belgium",
       "Azerbaijan", "Singapore", "Austin", "Mexico", "Brazil",
       "Abu Dhabi", "Monza","Qatar"]
year =2022
gps = ["Bahrain", "China", "Australia", "Japan",
       "Monaco", "Spain", "Canada", "Imola,"
       "Austria", "Great Britain", "Hungary", "Belgium",
       "Azerbaijan", "Singapore", "Austin", "Mexico", "Brazil",
       "Abu Dhabi", "Monza","Qatar","Miami"]

years = 2023
gps = ["Bahrain", "Saudi Arabia", "Australia", "Japan", "China",
       "Miami", "Imola", "Monaco", "Spain", "Canada",
       "Austria", "Great Britain", "Hungary", "Belgium", "Netherlands",
       "Azerbaijan", "Singapore", "Austin", "Mexico", "Brazil",
       "Qatar", "Abu Dhabi", "Monza"]

# %%
import fastf1
import pandas as pd

# Enable FastF1 cache
fastf1.Cache.enable_cache("/Users/ainefernandez/documents/itam/8SEMESTRE/F1 Python")

# Define the Grand Prix for each year
gps_by_year = {
    2019: ["Bahrain", "China", "Australia", "Japan", "Monaco", "Spain", "Canada", 
           "Austria", "Great Britain", "Hungary", "Belgium", "Azerbaijan", 
           "Singapore", "Austin", "Mexico", "Brazil", "Abu Dhabi", "Monza"],
    2020: ["Bahrain", "Monaco", "Spain", "Canada", "Austria", "Great Britain", 
           "Hungary", "Belgium", "Abu Dhabi", "Monza"],
    2021: ["Bahrain", "Monaco", "Spain", "Imola", "Austria", 
           "Great Britain", "Hungary", "Netherlands",
           "Belgium", "Azerbaijan",  "Austin", "Mexico", 
           "Brazil", "Abu Dhabi", "Monza", "Qatar","Saudi Arabia"],
    
    2022: ["Bahrain", "Australia", "Japan", "Monaco", "Spain", 
           "Canada", "Imola", "Austria", "Great Britain", "Hungary","Netherlands", 
           "Belgium", "Azerbaijan", "Singapore", "Austin", "Mexico", 
           "Brazil", "Abu Dhabi", "Monza", "Miami","Saudi Arabia"],
    
    2023: ["Bahrain", "Saudi Arabia", "Australia", "Japan",  
           "Miami", "Monaco", "Spain", "Canada", "Austria", 
           "Great Britain", "Hungary", "Belgium", "Netherlands", 
           "Azerbaijan", "Singapore", "Austin", "Mexico", "Brazil", 
           "Qatar", "Abu Dhabi", "Monza"]
}
# Function to label track status
def label_track_status(status):
    if pd.isna(status):
        return 'Unknown'
    status_str = str(status)  # Convert status to string for checking
    if '4' in status_str:
        return 'Safety Car'
    if '6' in status_str:
        return 'Virtual Safety Car'
    if '5' in status_str:
        return 'Red Flag'
    return {
        '1': 'Green flag',
        '2': 'Yellow flag',
    }.get(status_str, 'Unknown')

# Initialize an empty DataFrame to store all results
all_results = pd.DataFrame()

# Process each year separately
for year, gps in gps_by_year.items():
    for gp in gps:
        try:
            # Load the session for each Grand Prix
            session = fastf1.get_session(year, gp, 'R')
            session.load()

            # Extract all laps (from all drivers)
            laps = session.laps

            # Drop duplicate lap numbers (keeping only the first occurrence)
            laps = laps.drop_duplicates(subset='LapNumber', keep='first')

            # Label track statuses
            laps['Label'] = laps['TrackStatus'].apply(label_track_status)

            # Add the GP name and year columns
            laps['GP'] = gp
            laps['Year'] = year

            # Select only the necessary columns
            result = laps[['LapNumber', 'GP', 'Year', 'TrackStatus', 'Label']]

            # Append the result to the all_results DataFrame
            all_results = pd.concat([all_results, result], ignore_index=True)

        except Exception as e:
            # Handle exceptions (e.g., if the session data is not available)
            print(f"Could not load data for {gp} {year}: {e}")

# Save the complete DataFrame to a CSV file
all_results.to_csv('TesisSafetyCars2.csv', index=False)

# Print a success message
print("Data saved to 'TesisSafetyCars2.csv'")
# Out:
# core           INFO 	Loading data for Bahrain Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '16', '33', '5', '4', '7', '10', '23', '11', '99', '26', '20', '18', '63', '88', '27', '3', '55', '8']
# ...

# %%
import fastf1
import pandas as pd

# Enable FastF1 cache
fastf1.Cache.enable_cache("/Users/ainefernandez/documents/itam/8SEMESTRE/F1 Python")

# Define the Grand Prix for each year
gps_by_year = {
    2024: ["Bahrain", "Saudi Arabia", "Australia", "Japan", 
           "China", "Miami","Imola", "Monaco", "Spain", "Canada", "Austria", 
           "Great Britain", "Hungary", "Belgium", "Netherlands", "Monza","Azerbaijan","Singapore"]


}
# Function to label track status
def label_track_status(status):
    if pd.isna(status):
        return 'Unknown'
    status_str = str(status)  # Convert status to string for checking
    if '4' in status_str:
        return 'Safety Car'
    if '6' in status_str:
        return 'Virtual Safety Car'
    if '5' in status_str:
        return 'Red Flag'
    return {
        '1': 'Green flag',
        '2': 'Yellow flag',
    }.get(status_str, 'Unknown')

# Initialize an empty DataFrame to store all results
all_results = pd.DataFrame()

# Process each year separately
for year, gps in gps_by_year.items():
    for gp in gps:
        try:
            # Load the session for each Grand Prix
            session = fastf1.get_session(year, gp, 'R')
            session.load()

            # Extract all laps (from all drivers)
            laps = session.laps

            # Drop duplicate lap numbers (keeping only the first occurrence)
            laps = laps.drop_duplicates(subset='LapNumber', keep='first')

            # Label track statuses
            laps['Label'] = laps['TrackStatus'].apply(label_track_status)

            # Add the GP name and year columns
            laps['GP'] = gp
            laps['Year'] = year

            # Select only the necessary columns
            result = laps[['LapNumber', 'GP', 'Year', 'TrackStatus', 'Label']]

            # Append the result to the all_results DataFrame
            all_results = pd.concat([all_results, result], ignore_index=True)

        except Exception as e:
            # Handle exceptions (e.g., if the session data is not available)
            print(f"Could not load data for {gp} {year}: {e}")

# Save the complete DataFrame to a CSV file
all_results.to_csv('TesisSafetyCars2024.csv', index=False)

# Print a success message
print("Data saved to 'TesisSafetyCars2.csv'")
# Out:
# core           INFO 	Loading data for Bahrain Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '11', '55', '16', '63', '4', '44', '81', '14', '18', '24', '20', '3', '22', '23', '27', '31', '10', '77', '2']
# ...
