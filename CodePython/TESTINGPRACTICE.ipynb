# %%
import fastf1
import fastf1.plotting
import pandas as pd 
import numpy as np
import re
from matplotlib import pyplot as plt
print(fastf1.__version__)
from fastf1 import utils
from fastf1.core import Laps
import fastf1.plotting
import matplotlib.pyplot as plt


fastf1.plotting.setup_mpl(misc_mpl_mods=False)
# Out:
# 3.0.7

# %%
#Load Session
fastf1.Cache.enable_cache("/Users/ainefernandez/documents/itam/8SEMESTRE/F1 Python")
year=2024
wknd="Miami"
ses="FP1"
session = fastf1.get_session(year,wknd,ses)
session.load()
# Out:
# core           INFO 	Loading data for Miami Grand Prix - Practice 1 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# core        WARNING 	No result data for this session available on Ergast! (This is expected for recent sessions)
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '2', '3', '4', '10', '11', '14', '16', '18', '20', '22', '23', '24', '27', '31', '44', '55', '63', '77', '81']

# %%
fastf1.Cache.enable_cache("/Users/ainefernandez/documents/itam/8SEMESTRE/F1 Python")
year=2024
wknd="Bahrain"
ses=""
session = fastf1.get_testing_session(2024, 1, 3, backend=None)
session.load()
drivers = pd.unique(session.laps['Driver'])
lapdata=[]
for driver in drivers:
    laps=session.laps.pick_driver(driver)
    laps['LapTime'] = laps['LapTime'].dt.total_seconds()
    lapdata.append(laps)
    
all_laps = pd.concat(lapdata, ignore_index=True)   


print (all_laps['Team'])

# %%
teams=all_laps.groupby('Team')
print(teams)

# %%
average_laptimes = all_laps.groupby('Team')['LapTime'].mean()
average_laptimes

# %%
fastf1.Cache.enable_cache("/Users/ainefernandez/documents/itam/8SEMESTRE/F1 Python")
year=2023
wknd="Bahrain"
ses=""
session = fastf1.get_testing_session(2024, 1, 3, backend=None)
session.load()
drivers = pd.unique(session.laps['Driver'])
lapdata=[]
for driver in drivers:
    laps=session.laps.pick_driver(driver).pick_quicklaps()
    laps['LapTime'] = laps['LapTime'].dt.total_seconds()
    lapdata.append(laps)
    
all_laps2 = pd.concat(lapdata, ignore_index=True)   


print (all_laps2['Team'])

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 average_laptimes=all_laps2.groupby('Team')['LapTime'].mean()
#       3 hard = all_laps2[all_laps2['Compound'] == 'HARD']
#       4 medium=all_laps2[all_laps2['Compound'] == 'MEDIUM']
#
# NameError: name 'all_laps2' is not defined

# %%
average_laptimes
#average_laptimes.to_csv("RacePaceT3.csv")

# %%
average_laptimes_hard=hard.groupby('Team')['LapTime'].mean()
average_laptimes_hard
#average_laptimes_hard.to_csv("average_laptimes_hardT3.csv")

# %%
fastf1.Cache.enable_cache("/Users/ainefernandez/documents/itam/8SEMESTRE/F1 Python")
year=2023
wknd="Bahrain"
ses=""
session = fastf1.get_testing_session(2024, 1, 3, backend=None)
session.load()
driver="ZHO"
lap=session.laps.pick_driver(driver).pick_fastest()
print (lap)

#Telemetry
x = lap.telemetry['X']              
y = lap.telemetry['Y']
speed = lap.telemetry['Speed']
tel=pd.DataFrame({'X': x, 'Y': y,'Speed': speed })

tel.to_csv('ZHOT3.csv')

# %%
average_laptimes_medium=medium.groupby('Team')['LapTime'].mean()
average_laptimes_medium
average_laptimes_medium.to_csv("average_laptimes_mediumT3.csv")

# %%
average_laptimes_soft=soft.groupby('Team')['LapTime'].mean()
average_laptimes_soft
average_laptimes_soft.to_csv("average_laptimes_softT3.csv")

# %%
average_laptimes = pd.concat([average_laptimes_medium, average_laptimes_hard, average_laptimes_soft], ignore_index=True)

# Print the resulting DataFrame
print(average_laptimes)

# %%
fastf1.Cache.enable_cache("/Users/ainefernandez/documents/itam/8SEMESTRE/F1 Python")
year=2023
wknd="Bahrain"
ses=""
session = fastf1.get_testing_session(2024, 1, 3, backend=None)
session.load()
drivers = pd.unique(session.laps['Driver'])
list_fastest_laps = []
gapQ = pd.DataFrame(columns=['Driver', 'Gap'])


# Calculate fastest laps for each driver
for drv in drivers:
    drvs_fastest_lap = session.laps.pick_driver(drv).pick_fastest()
    list_fastest_laps.append(drvs_fastest_lap)

fastest_laps = fastf1.core.Laps(list_fastest_laps).sort_values(by='LapTime').reset_index(drop=True)
pole_lap = fastest_laps.iloc[0]  # Get the pole position lap

# Calculate and store gap in seconds
for index, row in fastest_laps.iterrows():
    gap = (row['LapTime'] - pole_lap['LapTime']).total_seconds()  # Calculate gap in seconds
    pos = {'Driver': row['Driver'], 'Gap': gap}
    gapQ = gapQ.append(pos, ignore_index=True)
print(gapQ)
#gapQ.to_csv("fastestT3.csv")
# Out:
# core           INFO 	Loading data for Pre-Season Testing - Practice 3 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	No lap data for driver 2
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate.
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '2', '3', '4', '10', '11', '14', '16', '18', '20', '22', '23', '24', '27', '31', '44', '55', '63', '77', '81']
#    Driver    Gap
# 0     LEC    0.0
# 1     RUS  0.046
# 2     ZHO  0.325
# 3     VER  0.433
# 4     TSU  0.453
# 5     ALB  0.662
# 6     PIA  0.708
# 7     ALO  0.837
# 8     SAI  0.925
# 9     PER  1.161
# 10    HUL  1.364
# 11    HAM  1.677
# 12    STR  1.716
# 13    NOR  1.786
# 14    GAS  1.827
# 15    MAG  2.731
# 16    OCO  2.757
# 17    BOT  3.206
# 18    RIC  6.693
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/2914751129.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gapQ = gapQ.append(pos, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/2914751129.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gapQ = gapQ.append(pos, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/2914751129.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gapQ = gapQ.append(pos, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/2914751129.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gapQ = gapQ.append(pos, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/2914751129.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gapQ = gapQ.append(pos, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/2914751129.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gapQ = gapQ.append(pos, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/2914751129.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gapQ = gapQ.append(pos, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/2914751129.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gapQ = gapQ.append(pos, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/2914751129.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gapQ = gapQ.append(pos, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/2914751129.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gapQ = gapQ.append(pos, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/2914751129.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gapQ = gapQ.append(pos, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/2914751129.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gapQ = gapQ.append(pos, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/2914751129.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gapQ = gapQ.append(pos, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/2914751129.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gapQ = gapQ.append(pos, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/2914751129.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gapQ = gapQ.append(pos, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/2914751129.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gapQ = gapQ.append(pos, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/2914751129.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gapQ = gapQ.append(pos, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/2914751129.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gapQ = gapQ.append(pos, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/2914751129.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gapQ = gapQ.append(pos, ignore_index=True)

# %%
laps_by_compound = all_laps.groupby(['Team', 'Compound']).size().reset_index(name='LapsCount')
print(laps_by_compound)
laps_by_compound.to_csv("lapsT3C.csv")

# %%
gapQ
# Out:
#    Driver    Gap
# 0     LEC    0.0
# 1     RUS  0.046
# 2     ZHO  0.325
# 3     VER  0.433
# 4     TSU  0.453
# 5     ALB  0.662
# 6     PIA  0.708
# 7     ALO  0.837
# 8     SAI  0.925
# 9     PER  1.161
# 10    HUL  1.364
# 11    HAM  1.677
# 12    STR  1.716
# 13    NOR  1.786
# 14    GAS  1.827
# 15    MAG  2.731
# 16    OCO  2.757
# 17    BOT  3.206
# 18    RIC  6.693

# %%
laps_total=all_laps.groupby(['Team']).size().reset_index(name='LapsCount')
print(laps_total)
laps_total.to_csv("lapsT3T.csv")

# %%
fastf1.Cache.enable_cache("/Users/ainefernandez/documents/itam/8SEMESTRE/F1 Python")
year=2024
wknd="Bahrain"
ses="FP2"
session = fastf1.get_session(year,wknd,ses)
session.load()
drivers = pd.unique(session.laps['Driver'])
lapdata=[]
for driver in drivers:
    laps=session.laps.pick_driver(driver).pick_quicklaps()
    laps['LapTime'] = laps['LapTime'].dt.total_seconds()
    lapdata.append(laps)
    
all_laps = pd.concat(lapdata, ignore_index=True)   


print (all_laps)
# Out:
# core           INFO 	Loading data for Bahrain Grand Prix - Practice 2 [v3.0.7]
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# core        WARNING 	No result data for this session available on Ergast! (This is expected for recent sessions)
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# req            INFO 	No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# _api           INFO 	Parsing car data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# _api           INFO 	Parsing position data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['1', '2', '3', '4', '10', '11', '14', '16', '18', '20', '22', '23', '24', '27', '31', '44', '55', '63', '77', '81']
#                       Time Driver DriverNumber  LapTime  LapNumber  Stint  \
# 0   0 days 00:26:43.362000    VER            1   91.271        2.0    1.0
# 1   0 days 00:32:58.929000    VER            1   91.161        5.0    1.0
# 2   0 days 00:44:52.379000    VER            1   90.851        8.0    2.0
# 3   0 days 00:56:27.736000    VER            1   97.007       11.0    3.0
# 4   0 days 00:58:04.450000    VER            1   96.714       12.0    3.0
# ..                     ...    ...          ...      ...        ...    ...
# 194 0 days 01:01:23.494000    PIA           81   96.820       16.0    3.0
# 195 0 days 01:03:00.456000    PIA           81   96.962       17.0    3.0
# 196 0 days 01:04:37.420000    PIA           81   96.964       18.0    3.0
# 197 0 days 01:14:42.656000    PIA           81   96.240       24.0    4.0
# 198 0 days 01:16:19.789000    PIA           81   97.133       25.0    4.0
#
#     PitOutTime PitInTime            Sector1Time            Sector2Time  ...  \
# 0          NaT       NaT 0 days 00:00:29.279000 0 days 00:00:39.044000  ...
# 1          NaT       NaT 0 days 00:00:29.249000 0 days 00:00:39.069000  ...
# 2          NaT       NaT 0 days 00:00:29.131000 0 days 00:00:38.834000  ...
# 3          NaT       NaT 0 days 00:00:31.246000 0 days 00:00:41.938000  ...
# 4          NaT       NaT 0 days 00:00:31.071000 0 days 00:00:41.783000  ...
# ..         ...       ...                    ...                    ...  ...
# 194        NaT       NaT 0 days 00:00:31.029000 0 days 00:00:41.708000  ...
# 195        NaT       NaT 0 days 00:00:31.231000 0 days 00:00:41.735000  ...
# 196        NaT       NaT 0 days 00:00:31.293000 0 days 00:00:41.642000  ...
# 197        NaT       NaT 0 days 00:00:30.784000 0 days 00:00:41.537000  ...
# 198        NaT       NaT 0 days 00:00:31.099000 0 days 00:00:41.996000  ...
#
#     FreshTyre             Team           LapStartTime            LapStartDate  \
# 0        True  Red Bull Racing 0 days 00:25:12.091000 2024-02-29 15:10:13.142
# 1        True  Red Bull Racing 0 days 00:31:27.768000 2024-02-29 15:16:28.819
# 2        True  Red Bull Racing 0 days 00:43:21.528000 2024-02-29 15:28:22.579
# 3       False  Red Bull Racing 0 days 00:54:50.729000 2024-02-29 15:39:51.780
# 4       False  Red Bull Racing 0 days 00:56:27.736000 2024-02-29 15:41:28.787
# ..        ...              ...                    ...                     ...
# 194     False          McLaren 0 days 00:59:46.674000 2024-02-29 15:44:47.725
# 195     False          McLaren 0 days 01:01:23.494000 2024-02-29 15:46:24.545
# 196     False          McLaren 0 days 01:03:00.456000 2024-02-29 15:48:01.507
# 197     False          McLaren 0 days 01:13:06.416000 2024-02-29 15:58:07.467
# 198     False          McLaren 0 days 01:14:42.656000 2024-02-29 15:59:43.707
#
#      TrackStatus  Position  Deleted  DeletedReason  FastF1Generated IsAccurate
# 0              1       NaN    False                           False       True
# 1              1       NaN    False                           False       True
# 2              1       NaN    False                           False       True
# 3              1       NaN    False                           False       True
# 4              1       NaN    False                           False       True
# ..           ...       ...      ...            ...              ...        ...
# 194            1       NaN    False                           False       True
# 195            1       NaN    False                           False       True
# 196            1       NaN    False                           False       True
# 197            1       NaN    False                           False       True
# 198            1       NaN    False                           False       True
#
# [199 rows x 31 columns]

# %%
average_laptimes=all_laps.groupby('Team')['LapTime'].mean()

hard = all_laps[all_laps['Compound'] == 'HARD']
medium=all_laps[all_laps['Compound'] == 'MEDIUM']
soft=all_laps[all_laps['Compound'] == 'SOFT']

# %%
average_laptimes_medium=medium.groupby('Team')['LapTime'].mean()
average_laptimes_medium
#average_laptimes_medium.to_csv("average_laptimes_mediumT3.csv")
# Out:
# Team
# Kick Sauber    93.163500
# McLaren        94.990571
# RB             93.318800
# Williams       92.604000
# Name: LapTime, dtype: float64

# %%
average_laptimes_soft=soft.groupby('Team')['LapTime'].mean()
average_laptimes_soft
#average_laptimes_soft.to_csv("average_laptimes_softT3.csv")
# Out:
# Team
# Alpine             96.133000
# Aston Martin       94.031000
# Ferrari            95.159778
# Haas F1 Team       95.267765
# Kick Sauber        96.615263
# McLaren            96.373850
# Mercedes           94.373917
# RB                 96.058312
# Red Bull Racing    95.582143
# Williams           94.656692
# Name: LapTime, dtype: float64

# %%
average_laptimes=all_laps.groupby('Team')['LapTime'].mean()
average_laptimes
# Out:
# Team
# Alpine             96.133000
# Aston Martin       94.031000
# Ferrari            95.159778
# Haas F1 Team       95.267765
# Kick Sauber        96.014957
# McLaren            96.015222
# Mercedes           94.373917
# RB                 95.406048
# Red Bull Racing    95.582143
# Williams           94.271813
# Name: LapTime, dtype: float64

# %%
#Ideal lap
fastf1.Cache.enable_cache("/Users/ainefernandez/documents/itam/8SEMESTRE/F1 Python")
year=2024
wknd="Bahrain"
ses="FP2"
session = fastf1.get_session(year, wknd, ses)
session.load()
drivers = pd.unique(session.laps['Driver'])
ideallaps = pd.DataFrame(columns=['Driver', 'Lap'])
for driver in drivers:
    laps = session.laps.pick_driver(driver)
    laps=laps.dropna(subset=['Sector1Time'])
    laps=laps.dropna(subset=['Sector2Time'])
    laps=laps.dropna(subset=['Sector3Time'])
    FS1 = min(laps['Sector1Time']).total_seconds()
    FS2 = min(laps['Sector2Time']).total_seconds()
    FS3 = min(laps['Sector3Time']).total_seconds()
    ILap = FS1 + FS2 + FS3
    lap = {'Driver': driver, 'Lap': ILap}
    ideallaps = ideallaps.append(lap,ignore_index=True)

print("IDEAL LAPS")
print(ideallaps)
fastestlap=min(ideallaps['Lap'])
idealgap = pd.DataFrame(columns=['Driver', 'Gap'])

for driver in drivers:
    gap = ideallaps[ideallaps['Driver'] == driver]['Lap'].iloc[0] - fastestlap
    gapQI = {'Driver': driver, 'Gap': gap}
    idealgap = idealgap.append(gapQI, ignore_index=True)

print("\nGap Fastest Lap:")
print(idealgap)
#idealgap.to_csv("idealgapABU.csv", index=False)

adf = pd.DataFrame(columns=['Driver', 'FastestLap'])
for driver in drivers:
    lap = session.laps.pick_driver(driver).pick_fastest()
    lt = lap["LapTime"]
    lt_seconds = lt.total_seconds()
    adf = adf.append({'Driver': driver, 'FastestLap': lt_seconds}, ignore_index=True)
print(adf)
gtl = pd.DataFrame(columns=['Driver', 'Gap'])
for driver in drivers:
    gap = adf[adf['Driver'] == driver]['FastestLap'].iloc[0] - ideallaps[ideallaps['Driver'] == driver]['Lap'].iloc[0]
    gtl = gtl.append({'Driver': driver, 'Gap': gap}, ignore_index=True)

# Print or save the 'gtl' DataFrame
print(gtl)
# Out:
# core           INFO 	Loading data for Bahrain Grand Prix - Practice 2 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# core        WARNING 	No result data for this session available on Ergast! (This is expected for recent sessions)
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '2', '3', '4', '10', '11', '14', '16', '18', '20', '22', '23', '24', '27', '31', '44', '55', '63', '77', '81']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ideallaps = ideallaps.append(lap,ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ideallaps = ideallaps.append(lap,ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ideallaps = ideallaps.append(lap,ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ideallaps = ideallaps.append(lap,ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ideallaps = ideallaps.append(lap,ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ideallaps = ideallaps.append(lap,ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ideallaps = ideallaps.append(lap,ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ideallaps = ideallaps.append(lap,ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ideallaps = ideallaps.append(lap,ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ideallaps = ideallaps.append(lap,ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ideallaps = ideallaps.append(lap,ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ideallaps = ideallaps.append(lap,ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ideallaps = ideallaps.append(lap,ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ideallaps = ideallaps.append(lap,ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ideallaps = ideallaps.append(lap,ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ideallaps = ideallaps.append(lap,ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ideallaps = ideallaps.append(lap,ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ideallaps = ideallaps.append(lap,ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ideallaps = ideallaps.append(lap,ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ideallaps = ideallaps.append(lap,ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   idealgap = idealgap.append(gapQI, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   idealgap = idealgap.append(gapQI, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   idealgap = idealgap.append(gapQI, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   idealgap = idealgap.append(gapQI, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   idealgap = idealgap.append(gapQI, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   idealgap = idealgap.append(gapQI, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   idealgap = idealgap.append(gapQI, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   idealgap = idealgap.append(gapQI, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   idealgap = idealgap.append(gapQI, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   idealgap = idealgap.append(gapQI, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   idealgap = idealgap.append(gapQI, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   idealgap = idealgap.append(gapQI, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   idealgap = idealgap.append(gapQI, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   idealgap = idealgap.append(gapQI, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   idealgap = idealgap.append(gapQI, ignore_index=True)
# IDEAL LAPS
#    Driver     Lap
# 0     VER  90.808
# 1     SAR  91.538
# 2     RIC  91.477
# 3     NOR  91.913
# 4     GAS  91.795
# 5     PER  91.097
# 6     ALO   90.65
# 7     LEC  90.951
# 8     STR  90.891
# 9     MAG  91.655
# 10    TSU  91.787
# 11    ALB  91.333
# 12    ZHO  92.006
# 13    HUL  90.884
# 14    OCO    91.9
# 15    HAM  90.374
# 16    SAI  90.769
# 17    RUS   90.58
# 18    BOT  92.001
# 19    PIA  90.784
#
# Gap Fastest Lap:
#    Driver    Gap
# 0     VER  0.434
# 1     SAR  1.164
# 2     RIC  1.103
# 3     NOR  1.539
# 4     GAS  1.421
# 5     PER  0.723
# 6     ALO  0.276
# 7     LEC  0.577
# 8     STR  0.517
# 9     MAG  1.281
# 10    TSU  1.413
# 11    ALB  0.959
# 12    ZHO  1.632
# 13    HUL   0.51
# 14    OCO  1.526
# 15    HAM    0.0
# 16    SAI  0.395
# 17    RUS  0.206
# 18    BOT  1.627
# 19    PIA   0.41
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   idealgap = idealgap.append(gapQI, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   idealgap = idealgap.append(gapQI, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   idealgap = idealgap.append(gapQI, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   idealgap = idealgap.append(gapQI, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   idealgap = idealgap.append(gapQI, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adf = adf.append({'Driver': driver, 'FastestLap': lt_seconds}, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adf = adf.append({'Driver': driver, 'FastestLap': lt_seconds}, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adf = adf.append({'Driver': driver, 'FastestLap': lt_seconds}, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adf = adf.append({'Driver': driver, 'FastestLap': lt_seconds}, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adf = adf.append({'Driver': driver, 'FastestLap': lt_seconds}, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adf = adf.append({'Driver': driver, 'FastestLap': lt_seconds}, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adf = adf.append({'Driver': driver, 'FastestLap': lt_seconds}, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adf = adf.append({'Driver': driver, 'FastestLap': lt_seconds}, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adf = adf.append({'Driver': driver, 'FastestLap': lt_seconds}, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adf = adf.append({'Driver': driver, 'FastestLap': lt_seconds}, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adf = adf.append({'Driver': driver, 'FastestLap': lt_seconds}, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adf = adf.append({'Driver': driver, 'FastestLap': lt_seconds}, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adf = adf.append({'Driver': driver, 'FastestLap': lt_seconds}, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adf = adf.append({'Driver': driver, 'FastestLap': lt_seconds}, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adf = adf.append({'Driver': driver, 'FastestLap': lt_seconds}, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adf = adf.append({'Driver': driver, 'FastestLap': lt_seconds}, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adf = adf.append({'Driver': driver, 'FastestLap': lt_seconds}, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adf = adf.append({'Driver': driver, 'FastestLap': lt_seconds}, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adf = adf.append({'Driver': driver, 'FastestLap': lt_seconds}, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   adf = adf.append({'Driver': driver, 'FastestLap': lt_seconds}, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gtl = gtl.append({'Driver': driver, 'Gap': gap}, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gtl = gtl.append({'Driver': driver, 'Gap': gap}, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gtl = gtl.append({'Driver': driver, 'Gap': gap}, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gtl = gtl.append({'Driver': driver, 'Gap': gap}, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gtl = gtl.append({'Driver': driver, 'Gap': gap}, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gtl = gtl.append({'Driver': driver, 'Gap': gap}, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gtl = gtl.append({'Driver': driver, 'Gap': gap}, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gtl = gtl.append({'Driver': driver, 'Gap': gap}, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gtl = gtl.append({'Driver': driver, 'Gap': gap}, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gtl = gtl.append({'Driver': driver, 'Gap': gap}, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gtl = gtl.append({'Driver': driver, 'Gap': gap}, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gtl = gtl.append({'Driver': driver, 'Gap': gap}, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gtl = gtl.append({'Driver': driver, 'Gap': gap}, ignore_index=True)
#    Driver FastestLap
# 0     VER     90.851
# 1     SAR     91.715
# 2     RIC     91.516
# 3     NOR     92.608
# 4     GAS     91.951
# 5     PER     91.115
# 6     ALO      90.66
# 7     LEC     91.113
# 8     STR     90.891
# 9     MAG     91.764
# 10    TSU     91.881
# 11    ALB     91.333
# 12    ZHO     92.048
# 13    HUL     90.884
# 14    OCO     92.027
# 15    HAM     90.374
# 16    SAI     90.769
# 17    RUS      90.58
# 18    BOT     92.001
# 19    PIA     90.784
#    Driver    Gap
# 0     VER  0.043
# 1     SAR  0.177
# 2     RIC  0.039
# 3     NOR  0.695
# 4     GAS  0.156
# 5     PER  0.018
# 6     ALO   0.01
# 7     LEC  0.162
# 8     STR    0.0
# 9     MAG  0.109
# 10    TSU  0.094
# 11    ALB    0.0
# 12    ZHO  0.042
# 13    HUL    0.0
# 14    OCO  0.127
# 15    HAM    0.0
# 16    SAI    0.0
# 17    RUS   -0.0
# 18    BOT    0.0
# 19    PIA    0.0
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gtl = gtl.append({'Driver': driver, 'Gap': gap}, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gtl = gtl.append({'Driver': driver, 'Gap': gap}, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gtl = gtl.append({'Driver': driver, 'Gap': gap}, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gtl = gtl.append({'Driver': driver, 'Gap': gap}, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gtl = gtl.append({'Driver': driver, 'Gap': gap}, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gtl = gtl.append({'Driver': driver, 'Gap': gap}, ignore_index=True)
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_89398/1015883988.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gtl = gtl.append({'Driver': driver, 'Gap': gap}, ignore_index=True)
